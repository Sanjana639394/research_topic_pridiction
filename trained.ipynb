# %%
import joblib

joblib.dump(models, 'model.pkl')
joblib.dump(countvector, 'countvector.pkl')
joblib.dump(tfidfvector, 'tfidfvector.pkl')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 import joblib
# ----> 3 joblib.dump(models, 'model.pkl')
#       4 joblib.dump(countvector, 'countvector.pkl')
#       5 joblib.dump(tfidfvector, 'tfidfvector.pkl')
#
# NameError: name 'models' is not defined
